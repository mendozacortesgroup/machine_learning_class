# %% [markdown]
# <center>
# <font size='7' style="color:#0D47A1">  <b>COURSE OF DIMENSIONALITY</b></font>
# </center>
#
# <hr style= "height:3px;">
# <br>

# %%
from IPython.display import Image

# %% [markdown]
# <br>
# <br>
# <br>
# <font size='6' style="color:#00A6D6">  <b>Introduction</b></font>

# %% [markdown]
# As the number of spatials dimensions goes up, finding things or measuring their size and shape gets harder, this phenomena is called the curse of dimensionality by the mathematician Richard Bellman.

# %% [markdown]
# <br>
# <br>
# <br>
# <font size='6' style="color:#00A6D6">  <b>Parallel Planes</b></font>

# %% [markdown]
# Given two planes, in how many points can they intersect?

# %% [markdown]
# In $R^3$ we have three options, they can not intersect, intersect in a line, or be the same plane.

# %% [markdown]
# But in $R^4$ things are more complicated, as they can intersect in a point.  More over the examples are easy to construct!

# %% [markdown]
# $A=\{(a,b,0,0)|\,a,b\in R\}$ and $B=\{(0,0,c,d)|\,c,d\in R\}$ they only share the point $(0,0,0,0)$.

# %% [markdown]
# <br>
# <br>
# <br>
# <font size='6' style="color:#00A6D6">  <b>From the inside of a sphere to the outside</b></font>

# %% [markdown]
# Imagine that we are just points on the real line.
#
# If I am in position 0 and Gabriel is in position 3, and we put a rock in position 1, then there is no way for Gabriel to reach me, as he can only move along the line.

# %% [markdown]
# But if we live in a plane, then Gabriel can just move around the point and still reach me without touching the rock.

# %%
Image("dimensionality/flat_earth.jpg")

# %% [markdown]
# Now suppose that there is a fence around me, like the circle of radious 1. Then Gabriel cannot reach me in the plane because the fence separated him from me.

# %% [markdown]
# Of course in $R^3$ all that Gabriel has to do, is to jump the fence, and he doesnt have to touch the fence.
#
# If now I am inside of a 2-sphere, Gabriel cannot reach me anymore.
#
# By continuing with this thinking you can realize that in 4 dimensions, it is possible to join the outside of a 2-sphere with the inside of the 2-sphere without crossing the boundary of the 2-sphere.

# %%
Image('dimensionality/ball.jpg')

# %% [markdown]
# <br>
# <br>
# <br>
# <font size='6' style="color:#00A6D6">  <b>Ghosts</b></font>

# %% [markdown]
# What do you think a two dimensional creature (or an animal with horizontal pupils ) see when a 3 dimensional animal jumps into the region of vision? It may look like the new animal appeared out of no where.

# %%
Image('dimensionality/goat-eyes.jpg')

# %% [markdown]
# In principle, if we have a rat (with horizontal pupils) in enclosed a maze, the rat may see us escaping the maze by crossing the 2-dimensional walls.
#
# Perhaps what we call ghost are just 4-dimentional entities, and we see them crosing walls and appearing out of nowhere but in fact they are using the 4th coordenate.

# %% [markdown]
# <br>
# <br>
# <br>
# <font size='6' style="color:#00A6D6">  <b>Barry Cipra's Sphere</b></font>

# %% [markdown]
# On a square of sides of lenght 4, acomodate 4 tangential unit disks and a smaller disk in the middle. The radious of the smallest disk is $\sqrt{2}-1$.

# %%
Image('dimensionality/cube.png')

# %% [markdown]
# In 3 dimensions, we have a cube with 8 unit balls, and a smaller ninth ball in the middle, whose radious is $\sqrt{3}-1.$

# %% [markdown]
# For $n$ dimensions, the box has a room for $2^n$ unit balls, with the one additional ball in the central space that has radious $\sqrt{n}-1$.
#
# For $n=9$ that ball has radious 2, twice the size of the other 512 balls and it is tangent to the walls. For $n>9$ the ball crosses the hypercube 'of side 4 even though it is "completely surrounded" by the unit-radius hyperspheres that "fill" the hypercube (in the sense of packing it)'.

# %% [markdown]
# <br>
# <br>
# <br>
# <font size='6' style="color:#00A6D6">  <b>Sampling</b></font>

# %% [markdown]
# 10^2 evenly spaced points suffice to sample a unit interval with no more than .001 distance between points.
# In $R^{10}$ to sample the hypercube with a lattice that has a spacing of .001 between adjacent points would require ${10^2}^{10}$ sample points.

# %% [markdown]
# <br>
# <br>
# <br>
# <font size='6' style="color:#00A6D6">  <b>Density</b></font>

# %% [markdown]
# Most of the volume of the hypercube is near the borders. Consider a hypercube of side 1. If you cut a slice of the cube near a face, of volume $1x1x\epsilon$, then the higher the dimension, the more faces the hypercube have, and so, even with the same volume, those slices amount for a higher percentage of the total volume.
#
# It can be shown that most of the surface area of the hyper sphere is around the equator.

# %% [markdown]
#     If a constant number of examples is distributed uniformly in a high dimensional hypercube,
#     beyond some dimensionality most examples are closer to a face of the hypercube than to their
#     nearest neighbor.

# %% [markdown]
# We consider a ball of radious 1 inside a cube of side 2. The ball touches the sides.
#
# What fraction of the cube is filled by the ball?
#
#     In one dimension, the ball and the cube coincide, so the answer is 1.
#
#     In two dimensions, a 2-ball inside a 2-cube is a disk inside a square, so the ratio is about .79.
#
#     In three dimensions the ratio is approximately .52.
#
# In general the hyper cube has volume $2^d$, while the volume of the hyper sphere of radious 1 is given by:
# $\frac{\pi^{d/2}}{\Gamma(d/2+1)}$, this gamma function is an extension of the factorial:
# $\Gamma(n+1)=n!$ for non integrers, so we can ask things like what is $\Gamma(1/2)? \sqrt{\pi}.$
#
# We find the volume of the hyper sphere's in the following table:

# %%
Image("dimensionality/table.jpg")

# %% [markdown]
# With values like $10^{-40}$ for 100 dimensions... and since the cube volume grows, for 100 dimensions the quotient of the ball volume by the cube volume has declined to $1.8x10^{-70}.$

# %% [markdown]
#     "smaller than the volume of an atom in relation to the volume of the earth"

# %% [markdown]
# Remember that the surfice of the ball touches every side of the cube!

# %% [markdown]
# Since a 100-cube has 200 faces and $2^{100}$ corners, we should blame on those corners. Lets consider diameters of the cube, lines between points of the cube that pass through the origin. The minimum diameter  is two, but the largest  is $2*\sqrt{n}$, so for 100 dimensions, we have the lenght to be 20, and only 10% is within the ball! there will be 100 of the short ones and $2^{99}$ of the long ones.

# %% [markdown]
# <br>
# <br>
# <br>
# <font size='6' style="color:#00A6D6">  <b>Adversarial Negatives</b></font>

# %% [markdown]
# The following comes from:
#  "Intriguing properties of neural networks"

# %%
Image("dimensionality/int.png")

# %% [markdown]
# from reddit:
#     The ability to generate these "adversarial examples" was explained by the fact that almost all of the volume of a high dimensional sphere is at the surface. The percent of the volume of an n-sphere contained within, say, 0.1*radius of the surface, is ~100% for large n. So the fact that each point was within some epsilon of a decision boundary was counter intuitive, but ultimately a predictable consequence of the nature of high dimensional spaces. Thankfully, almost all the (hyper)volume around each image is in the correct decision (hyper)volume [almost all minute perturbations to a correctly classified image leave it correctly classified].

# %%
Image("dimensionality/Layers.jpg")

# %% [markdown]
#      The intriguing conclusion is that the adversarial examples remain hard for models trained even on a disjoint training set, although their effectiveness decreases considerably.

# %% [markdown]
# <br>
# <br>
# <br>
# <font size='6' style="color:#00A6D6">  <b>KNN</b></font>

# %% [markdown]
# kNN in low dimensions have to select among the closest points. In higher dimensions there may be too many points nearby and so the choice seems random.  Actually, there is a more serious problem for KNN.
#
#
# Let's work with the unit hypercube. Fix a random corner. We find that there are n corners with in distance 1. ${n\choose 2}$ with in distance $\sqrt{2}$, ${n\choose 2}$ with in distance $\sqrt{3},\cdots, {n \choose n/2}$ corners within distance $\sqrt{n/2}\cdots$ until one last point with distance $\sqrt{n}.$
#
#
# We know that ${n \choose n/2}$ is the biggest binomial coefficient, so it contains most corners, more over the values around $\sqrt{n}$ differ by little to it, so the distribution of points by distance is  skew and centered near that value.

# %%
from IPython.display import Image
Image("dimensionality/dim.png")

# %% [markdown]
# It can be shown that if the data is independent and identically distributed, the ratio between the nearest and farthest points approaches most of the time, i.e. the points essentially become uniformly distant from each other. This phenomenon can be observed for wide variety of distance metrics, but it is more pronounced for the Euclidean metric.

# %% [markdown]
# On the other hand, among all possible $L^k$ metrics, the $L^1$ and $L^2$ are better.

# %%
Image('dimensionality/distances.png')

# %%
Image('dimensionality/dimen.png')

# %% [markdown]
# Fortunately, there is an effect that partly counteracts the
# curse, which might be called the“blessing of non-uniformity.”
# In most applications examples are not spread uniformly throughout
# the instance space, but are concentrated on or near
# a lower-dimensional manifold. For example, k-nearest neighbor
# works quite well for handwritten digit recognition even
# though images of digits have one dimension per pixel, because
# the space of digit images is much smaller than the
# space of all possible images.

# %% [markdown]
# <br>
# <br>
# <br>
# <font size='6' style="color:#00A6D6">  <b>Homework</b></font>

# %% [markdown]
# Write a the equation of a path in $R^4$ from the point $(0,0,0,0)$ to the point $(1,0,0,0)$ without touching the sphere $\{(x,y,z,0)|x^2+y^2+z^2=1\}.$
#
#
#
# Other norms and measures.
#
# We denote by $|| ◦ ||′: R\times R^3 → R$ the norm $||(x_0,x_1, x2, x3)||′ = max\{||(x_0, x_1)||, ||(x_0, x_2)||, ||(x_0, x_3)||\}$, where $||(a,b)|| =\sqrt{a^2+b^2}$. We call $|| ◦ ||′$ the Wispy norm.
#
# Let $B(0, r) := \{x ∈ R\times R^3| \sqrt{\sum x_i^{ 1/2}} < r\}, B′(0, r) := \{x ∈ H| ||x||^{ 1/2} < r\}$. Find $vol(B(0, 1)) / vol(B′(0, 1)).$

# %%
Image('dimensionality/sim.png')

# %% [markdown]
# Given $S=[0,1,\cdots,100],$ we consider the distance among points. We can extend this to a distance on subsets of $S$ as $d(A,B)=min\{ d(x,y)|x\in A, y\in B\}$.
#
# Calculate $simcos_4(\{0, 10, 20,\cdots,100\},\{3,45\})$.
#
# Calculate $simcos_{12}(\{0, 50,100\},\{10,11,\cdots,40\})$.

# %% [markdown]
# <br>
# <br>
# <br>
# <font size='6' style="color:#00A6D6">  <b>References</b></font>

# %% [markdown]
# An Adventure in the Nth Dimension:
# https://www.americanscientist.org/article/an-adventure-in-the-nth-dimension
#
# When Is “Nearest Neighbor” Meaningful?:
# https://members.loria.fr/MOBerger/Enseignement/Master2/Exposes/beyer.pdf
#
# On the Surprising Behavior of Distance Metrics in High Dimensional Space:
# http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.23.7409&rep=rep1&type=pdf
#
# A Few Useful Things to Know about Machine Learning:
# https://homes.cs.washington.edu/~pedrod/papers/cacm12.pdf
#
# Intriguing properties of neural networks:
# https://arxiv.org/pdf/1312.6199.pdf
#
# Can Shared-Neighbor Distances Defeat the Curse of Dimensionality?
# http://www.dbs.ifi.lmu.de/~zimek/publications/SSDBM2010/SNN-SSDBM2010-preprint.pdf
#
# Reddit:
# https://www.reddit.com/r/math/comments/2yrxaj/a_really_interesting_result_about/
