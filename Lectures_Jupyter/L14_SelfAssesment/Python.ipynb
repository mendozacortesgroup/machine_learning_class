# %% [markdown]
# # Codingame
#
# This website has games that you can play, in order to win you have to use a particular skill from programming.

# %%
from IPython.display import Image
Image("https://static-aznet.codingame.com/common/images/leaderboards/header.0d0c1cf6.jpg")

# %% [markdown]
# This is my invitation code:
# https://www.codingame.com/servlet/urlinvite?u=1767339

# %% [markdown]
# After you register, add company "Florida State University - Department of Scientific Computing"
# FSU as school  and add "Rubiel" as a friend:

# %% [markdown]
# https://www.codingame.com/profile/4d6594efa9ee8ba1ae9eca9f88a62edb9337671

# %% [markdown]
# If you are new to programming start in this section:
# https://www.codingame.com/training/easy

# %% [markdown]
# If you are advanced, you can start programming the cars here:
#
# https://www.codingame.com/multiplayer/bot-programming/mean-max

# %%
Image("download.png")

# %% [markdown]
# Read the instructions and be careful with the output, a specific format is needed.

# %% [markdown]
# If you want, I can give you my scheleton, but first try to make the cars move.
