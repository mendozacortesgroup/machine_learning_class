# %%
from IPython.display import Image

# %% [markdown]
# #  Operads.
# Examples.

# %%
# Trees

# %%
# Feyman diagrams.

# %%
# Tubes

# %%
# Open closed topological quantum field theories

# %% [markdown]
# # Cycles and homology.

# %% [markdown]
# I like to think of transition states as oriented labeled graphs. There is a well defined notion of boundary operator for graphs:

# %%
Image("C:/Users/FSU/Dropbox/Teaching/2018_Spring_Machine_Learning_Class/Lectures_Jupyter/L9_Reaction_Networks/boundaries.png")

# %% [markdown]
# But not every possible element in the boundary has sense in Chemistry, still, if we remove the terms that are disconnected we obtain a new operation.

# %%
Image("C:/Users/FSU/Dropbox/Teaching/2018_Spring_Machine_Learning_Class/Lectures_Jupyter/L9_Reaction_Networks/boundaries2.png")

# %% [markdown]
# What are the figures associated to a particular chemical reaction?
# What is the meaning of the cycles?
# if we find a cycle, can we remove it and have a cheaper reaction?
